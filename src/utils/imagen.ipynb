# %%
from IPython.display import Image, display

display(Image(filename=r"C:\Users\jrtm2\Desktop\SQL_projectA\src\img\1.png"))

# %% [markdown]
# Este fue el primer planteamiento del proyecto. Aquí nos hicimos una ligera idea de como íbamos a distribuir las tablas.

# %%
from IPython.display import Image, display

display(Image(filename=r"C:\Users\jrtm2\Desktop\SQL_projectA\src\img\2.png"))

# %% [markdown]
# Este fue el planteamiento final de como organizar las tablas y así trabajarlas en Python y SQL

# %%
from IPython.display import Image, display

display(Image(filename=r"C:\Users\jrtm2\Desktop\SQL_projectA\src\img\3.png"))

# %% [markdown]
# Modelo entidad relación. Distribución del proyecto y de todas las distribuciones de las mismas.
